# %% [markdown]
# # Probamos varios modelos de recomendación

# %% [markdown]
# # 1.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import hstack, csr_matrix
from sklearn.preprocessing import StandardScaler



def recomendacion(titulo):

    # Cargar datos dentro de la función
    movies_df = pd.read_parquet('../Datasets/movies.parquet')

    # Asegúrate de que la columna de título esté en minúsculas para la búsqueda
    titulo = titulo.lower()
    
    # Filtra el DataFrame para la película de entrada
    pelicula = movies_df[movies_df['title'].str.lower() == titulo]
    
    if pelicula.empty:
        return "Película no encontrada."
    
    # Preparar datos para vectorización
    # Crear el vectorizador para el título
    title_vectorizer = TfidfVectorizer(stop_words='english')
    # Crear el codificador para el género
    genre_encoder = OneHotEncoder(sparse_output=True, handle_unknown='ignore')
    
    # Encajamos el codificador y el vectorizador
    title_vectorizer.fit(movies_df['title'])
    genre_encoder.fit(movies_df['genre_name'].apply(lambda x: x.split('|')).tolist())
    
    # Transformamos los datos
    title_vectors = title_vectorizer.transform(movies_df['title'])
    genre_vectors = genre_encoder.transform(movies_df['genre_name'].apply(lambda x: x.split('|')).tolist())
    popularity = movies_df['popularity'].values.reshape(-1, 1)
    
    # Normalizamos la popularidad
    scaler = StandardScaler()
    popularity = scaler.fit_transform(popularity)
    
    # Convertimos popularidad a una matriz dispersa
    popularity = csr_matrix(popularity)
    
    # Concatenamos todos los vectores
    combined_vectors = hstack([title_vectors, genre_vectors, popularity])
    
    # Encuentra el índice de la película de entrada
    idx = movies_df.index[movies_df['title'].str.lower() == titulo].tolist()[0]
    
    # Calcula la similitud de coseno
    cosine_sim = cosine_similarity(combined_vectors[idx:idx+1], combined_vectors).flatten()
    
    # Crea una lista de similitud excluyendo la película de entrada
    sim_scores = list(enumerate(cosine_sim))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Obtén las 5 películas más similares
    sim_scores = sim_scores[1:6]
    movie_indices = [i[0] for i in sim_scores]
    
    # Devuelve los nombres de las películas recomendadas
    recommended_movies = movies_df['title'].iloc[movie_indices].tolist()
    
    return recommended_movies

# Ejemplo de uso
# movies_df = pd.read_csv('path_to_movies_data.csv')
print(recomendacion('toy story'))
# Out:
# ['Toy Story 2', 'Toy Story 3', 'Up', '9', 'Your Name.']

# %% [markdown]
# # 2.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import hstack
import numpy as np

# Cargar datos
movies_df = pd.read_parquet('../Datasets/movies.parquet')

# Agrupar los géneros por título para evitar duplicados
movies_df_grouped = movies_df.groupby('title').agg({
    'genre_name': lambda x: list(set(x)),  # Crear una lista única de géneros
    'popularity': 'first',
    'release_date': 'first',
    'budget': 'first',
    'revenue': 'first',
    'runtime': 'first',
    'vote_average': 'first',
    'vote_count': 'first',
    'release_year': 'first',
    'id_movie': 'first'
}).reset_index()

def recomendacion(titulo, movies_df_grouped, randomize=True, genre_weight=3):
    titulo = titulo.lower()
    
    pelicula = movies_df_grouped[movies_df_grouped['title'].str.lower() == titulo]
    
    if pelicula.empty:
        return "Película no encontrada."
    
    # Vectorizar los títulos
    title_vectorizer = TfidfVectorizer(stop_words='english')
    title_vectors = title_vectorizer.fit_transform(movies_df_grouped['title'])
    
    # Codificar los géneros
    genre_encoder = MultiLabelBinarizer()
    genre_vectors = genre_encoder.fit_transform(movies_df_grouped['genre_name'])
    
    # Ponderar más los géneros
    genre_vectors = genre_vectors * genre_weight
    
    # Combinar vectores de título y género
    combined_vectors = hstack([title_vectors, genre_vectors]).tocsr()
    
    # Obtener el índice de la película de entrada
    idx = movies_df_grouped.index[movies_df_grouped['title'].str.lower() == titulo].tolist()[0]
    
    # Calcular la similitud de coseno
    input_vector = combined_vectors[idx]
    cosine_sim = cosine_similarity(input_vector, combined_vectors).flatten()
    
    # Excluir la película de entrada y ordenar por similitud
    sim_scores = sorted(list(enumerate(cosine_sim)), key=lambda x: x[1], reverse=True)
    sim_scores = [score for score in sim_scores if score[0] != idx]
    
    # Seleccionar las películas recomendadas (máximo 5)
    recommended_titles = set()
    top_similar = [score for score in sim_scores if score[1] > 0.7]  # Filtrar las más similares
    
    if len(top_similar) >= 5:
        selected_similar = np.random.choice([score[0] for score in top_similar], 5, replace=False)
    else:
        selected_similar = [score[0] for score in top_similar[:5]]
    
    for movie_index in selected_similar:
        movie_title = movies_df_grouped['title'].iloc[movie_index]
        recommended_titles.add(movie_title)
    
    final_recommendations = list(recommended_titles)
    
    if len(final_recommendations) == 0:
        return "No hay suficientes recomendaciones disponibles."

    return final_recommendations

# Ejemplo de uso
print(recomendacion('GoldenEye', movies_df_grouped, randomize=True, genre_weight=3))
# Out:
# ['Krakatoa, East of Java', 'The Son of Monte Cristo', 'Blackbeard, the Pirate', 'X-Men: The Last Stand', 'Bang Bang!']

# %% [markdown]
# # 3. Este fue el mejor modelo de los 3

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import hstack
import numpy as np


def recomendacion(titulo, randomize=True, genre_weight=3):

    # Datos
    movies_df = pd.read_parquet('../Datasets/movies_df.parquet')

    # Agrupar los géneros por título para evitar duplicados
    movies_df_grouped = movies_df.groupby('title').agg({
    'genre_name': lambda x: list(set(x))
    }).reset_index()

    titulo = titulo.lower()
    
    pelicula = movies_df_grouped[movies_df_grouped['title'].str.lower() == titulo]
    
    if pelicula.empty:
        return "Película no encontrada."
    
    # Vectorizar los títulos
    title_vectorizer = TfidfVectorizer(stop_words='english')
    title_vectors = title_vectorizer.fit_transform(movies_df_grouped['title'])
    
    # Codificar los géneros
    genre_encoder = MultiLabelBinarizer()
    genre_vectors = genre_encoder.fit_transform(movies_df_grouped['genre_name'])
    
    # Ponderar más los géneros
    genre_vectors = genre_vectors * genre_weight
    
    # Combinar vectores de título y género
    combined_vectors = hstack([title_vectors, genre_vectors]).tocsr()
    
    # Obtener el índice de la película de entrada
    idx = movies_df_grouped.index[movies_df_grouped['title'].str.lower() == titulo].tolist()[0]
    
    # Calcular la similitud de coseno
    input_vector = combined_vectors[idx]
    cosine_sim = cosine_similarity(input_vector, combined_vectors).flatten()
    
    # Excluir la película de entrada y ordenar por similitud
    sim_scores = sorted(list(enumerate(cosine_sim)), key=lambda x: x[1], reverse=True)
    sim_scores = [score for score in sim_scores if score[0] != idx]
    
    # Seleccionar las películas recomendadas (máximo 5)
    recommended_titles = set()
    top_similar = [score for score in sim_scores if score[1] > 0.7]  # Filtrar las más similares
    
    if len(top_similar) >= 5:
        selected_similar = np.random.choice([score[0] for score in top_similar], 5, replace=False)
    else:
        selected_similar = [score[0] for score in top_similar[:5]]
    
    for movie_index in selected_similar:
        movie_title = movies_df_grouped['title'].iloc[movie_index]
        recommended_titles.add(movie_title)
    
    final_recommendations = list(recommended_titles)
    
    if len(final_recommendations) == 0:
        return "No hay suficientes recomendaciones disponibles."

    return final_recommendations

# Ejemplo de uso correcto
pelicula_recomendada = "Toy Story"  # Aquí simplemente asignas el nombre de la película directamente
print(recomendacion(pelicula_recomendada))
# Out:
# ['Space Chimps', 'Batman Beyond: Return of the Joker', 'Ice Age: The Great Egg-Scapade', "It's the Great Pumpkin, Charlie Brown", 'Rhinoceros']

# %% [markdown]
# # Pruebas de precision

# %%
import pandas as pd

def evaluate_recommendations(test_df, recommender_func):
    results = []
    
    for _, row in test_df.iterrows():
        title = row['title']
        expected_recommendations = set(row['expected_recommendations'])
        recommended_titles = recommender_func(title)
        
        if isinstance(recommended_titles, str):  # Verifica si el resultado es un mensaje de error
            recommended_titles = set()
        else:
            recommended_titles = set(recommended_titles)
        
        # Depurar
        print(f"Title: {title}")
        print(f"Expected Recommendations: {expected_recommendations}")
        print(f"Recommended Titles: {recommended_titles}")
        
        # Calcular precisión y recuperación
        true_positive = len(expected_recommendations & recommended_titles)
        precision = true_positive / len(recommended_titles) if len(recommended_titles) > 0 else 0
        recall = true_positive / len(expected_recommendations) if len(expected_recommendations) > 0 else 0
        
        # Depurar los cálculos
        print(f"True Positives: {true_positive}")
        print(f"Precision Calculation: {true_positive} / {len(recommended_titles)}")
        print(f"Recall Calculation: {true_positive} / {len(expected_recommendations)}")
        
        results.append({
            'title': title,
            'precision': precision,
            'recall': recall
        })
    
    return pd.DataFrame(results)

# Evaluar recomendaciones
evaluation_results = evaluate_recommendations(recomendacion)
print(evaluation_results)
# Out:
# Similitudes para goldeneye:
# A Dangerous Man: 0.9642857142857144
# A View to a Kill: 0.9642857142857144
# A Viking Saga: The Darkest Day: 0.9642857142857144
# Angel of Destruction: 0.9642857142857144
# Arabesque: 0.9642857142857144
# As Good As Dead: 0.9642857142857144
# Ballistic: Ecks vs. Sever: 0.9642857142857144
# Beatdown: 0.9642857142857144
# Behind Enemy Lines II: Axis of Evil: 0.9642857142857144
# Black Dog: 0.9642857142857144
# Title: GoldenEye
# Expected Recommendations: {'Tomorrow Never Dies', 'The World Is Not Enough', 'Die Another Day'}
# Recommended Titles: {'A Common Man', 'Fire Birds', 'Largo Winch II', 'Thunderheart', 'Mission: Impossible - Ghost Protocol', 'Without a Paddle', 'Death Wish 4: The Crackdown', 'The Chosen One: Legend of the Raven', 'The Mechanik', 'The Minion', 'Vettaiyaadu Vilaiyaadu', 'Battleship', 'Jaws: The Revenge', 'Hard to Kill', 'Ultimate Heist', 'Cover-Up', 'On Deadly Ground', 'Krakatoa, East of Java', 'Cave', 'Anacondas: The Hunt for the Blood Orchid', 'The River Wild', 'Live and Let Die', 'Demolition University', 'Game of Death', 'Diablo', 'The Third Wave', 'Fantasy Mission Force', 'Death Racers', 'Sudden Death', 'A Dark Truth', 'Trader Horn', 'Striking Range', 'Blood Father', 'Civic Duty', 'Bulldog Drummond at Bay', 'Mercury Man', 'Shadow Conspiracy', 'Legendary: Tomb of the Dragon', 'Black Dog', 'Agent Red', 'Coronado', 'The Count of Monte Cristo', 'Malone', 'Overdrive', 'Die Hard: With a Vengeance', 'Octopussy', 'The Forsaken', 'Password: Uccidete agente Gordon', 'The Hangman', 'The Legend of Zorro', 'The Evil That Men Do', 'Johan Falk: Vapenbröder', 'Stash House', 'Terminator Genisys', 'Scarface', 'Hard Target', 'Killing Season', "On Her Majesty's Secret Service", 'Behind Enemy Lines', 'Dr. No', 'Passenger 57', 'Carjacked', 'First Kill', 'Pirates: Blood Brothers', 'The Target', 'Raiders of the Lost Ark - The Adaptation', 'Vendetta', 'Missionary Man', 'Waist Deep', 'Jungleground', 'The Black Knight', 'Hardwired', 'Bloodmoon', 'Icebreaker', 'Vertical', 'The Hard Corps', 'Firefox', 'The Viking Queen', 'Chronicles of the Ghostly Tribe', 'The General Died at Dawn', 'F/X2', "Airport '77", 'The Day of the Jackal', 'Moby Dick', 'Cat Chaser', "Carlito's Way: Rise to Power", 'Kickboxer', 'Lady Bloodfight', 'The Tale of Zatôichi Continues', 'Mad Max 2: The Road Warrior', 'The Hero: Love Story of a Spy', 'The Advocate: A Missing Body', '3000 Miles to Graceland', 'The Poseidon Adventure', 'Extinction: Nature Has Evolved', 'For Your Eyes Only', 'Titanic 2', 'A Force of One', 'Secret Agent Super Dragon', 'Hells Angels on Wheels', 'Ballistic: Ecks vs. Sever', 'Never Say Never Again', 'Star Trek V: The Final Frontier', 'The Warriors', 'G.I. Joe: The Rise of Cobra', 'A Lonely Place to Die', 'Sparks', 'Shadow Man', 'Bare Knuckles', "Tarzan's Savage Fury", 'Tarzan and the Lost City', '13 Tzameti', 'Firepower', 'A Better Way to Die', 'Who Dares Wins', 'Johnny Cool', 'The Expendables 3', 'Brake', '16 Blocks', 'One in the Chamber', 'Rampage', 'First Blood', 'The Professional', 'Extortion', 'Escape from L.A.', 'Chrome and Hot Leather', 'Jason Bourne', 'Downtown', 'Two Tigers', 'Ong Bak 2', 'The Doll Squad', 'Shiri', 'V.I. Warshawski', 'The Octagon', 'Extraction', 'Ronin', 'The Marine', 'Blast', "Assassin's Bullet", 'The Cave', 'The Fifth Element', 'The Conqueror', 'Against All Flags', 'The Living Daylights', 'Stealth Fighter', 'The Pink Jungle', 'The Towering Inferno', 'Johan Falk: Operation Näktergal', 'The 36th Chamber of Shaolin', 'When Time Ran Out...', 'Agent for H.A.R.M.', 'Skyjacked', 'Gun', 'Persecuted', 'Desert Saints', 'The Fighting Prince of Donegal', 'The Huns', 'Angelfist', 'The Whistle Blower', 'Night Train to Mundo Fine', 'Albino', 'Hotel California', 'Dragonball Evolution', 'Bloodsport III', 'The Heavy', 'Come Drink with Me', 'Red Billabong', 'The Matrix Reloaded', 'American Perfekt', 'Extreme Justice', 'The Fifth Commandment', 'Vengeance: A Love Story', 'The 7 Adventures of Sinbad', 'The Day After Tomorrow', 'Into the Blue', 'Moonraker', 'Angel of Destruction', 'Penitentiary II', 'Ironmaster', 'Predators', "China O'Brien", 'Lightning Bolt', 'The Losers', 'Jurassic World', "The Tiger: An Old Hunter's Tale", 'Indiana Jones and the Temple of Doom', 'Caged Women', 'Delta Force 3: The Killing Game', 'Legionnaire', 'The Contractor', 'Blunt Force Trauma', 'Slove', 'An Empress and the Warriors', 'Sniper: Legacy', 'Fantastic 4: Rise of the Silver Surfer', 'Raiders of the Lost Ark', 'Surviving the Game', 'Total Recall', 'The Hunt for Red October ...
# True Positives: 3
# Precision Calculation: 3 / 773
# Recall Calculation: 3 / 3
# Similitudes para toy story:
# Toy Story 2: 1.0
# Toy Story 3: 1.0
# Toy Story of Terror!: 0.9936096415994076
# A Boy Named Charlie Brown: 0.9642857142857144
# A Close Shave: 0.9642857142857144
# A Flintstones Christmas Carol: 0.9642857142857144
# A Matter of Loaf and Death: 0.9642857142857144
# Ali Baba Bunny: 0.9642857142857144
# Amazon Jack 3: Jungo Goes Bananas: 0.9642857142857144
# An All Dogs Christmas Carol: 0.9642857142857144
# Title: Toy Story
# Expected Recommendations: {"A Bug's Life", 'Toy Story 2', 'Monsters, Inc.'}
# Recommended Titles: {'WALL·E', 'Dinosaur', 'Rabbit Seasoning', 'Blank Check', "Good Luck Charlie, It's Christmas!", 'Tinker Bell and the Pirate Fairy', 'Scooby-Doo! And the Legend of the Vampire', 'Scooby-Doo! Camp Scare', 'Santa with Muscles', 'Ernest Rides Again', "The Bear That Wasn't", 'Big Top Scooby-Doo!', 'Ernest Goes to Jail', 'Diary of a Wimpy Kid: Rodrick Rules', 'Oh How It Hurts 66', 'Fantastic Mr. Fox', 'Santa Claus and the Magic Drum', 'A Monster in Paris', 'Pinocchio', 'Christmas Carol: The Movie', 'Partysaurus Rex', 'George !', 'Judy Moody and the Not Bummer Summer', "Last Year's Snow Was Falling", 'Krummerne', 'Here Comes Peter Cottontail', 'VeggieTales: Very Silly Songs', "What's Opera, Doc?", 'Saving Christmas', 'Creature Comforts', "Santa's Apprentice", 'The Key to Paradise', 'A Family Affair', 'Harry and the Butler', "Hey There, It's Yogi Bear", 'Irena do domu!', 'Corner Gas: The Movie', "VeggieTales: Minnesota Cuke and the Search for Samson's Hairbrush", 'Planes: Fire & Rescue', 'Norm of the North', 'Cheaper by the Dozen', 'Moomins on the Riviera', 'The Great Piggy Bank Robbery', 'Sly Cooper', 'Cars 3', 'Mower Minions', 'Take Away', 'Tenchi Muyô! In Love', 'Minions: Orientation Day', 'Jinxy Jenkins, Lucky Lou', "The Legend of Mor'du", 'George & A.J.', 'Stuart Little 2', 'Pokémon: Arceus and the Jewel of Life', "Bosko's Parlor Pranks", 'The Brave Little Toaster Goes to Mars', 'Ratatouille', 'The Lego Batman Movie', 'Gus', 'Hemo The Magnificent', 'Maktub', 'Sunshine Barry & the Disco Worms', 'Fresh Hare', 'Hoodwinked Too! Hood VS. Evil', 'A Nanny for Christmas', 'Scooby-Doo! and the Reluctant Werewolf', 'Barbie as The Princess & the Pauper', 'The Lizzie McGuire Movie', 'Barnyard', 'BURN·E', 'The Republic of ShKID', 'Popeye the Sailor Meets Sindbad the Sailor', 'Outrageous!', 'The Secret of NIMH 2: Timmy to the Rescue', 'A Christmas Story', "101 Dalmatians II: Patch's London Adventure", 'Free Birds', 'Zarafa', 'The Missing Lynx', 'Despicable Me 2', 'Chasing Christmas', 'VeggieTales: Duke and the Great Pie War', 'License to Drive', 'Ramona and Beezus', 'Dennis the Menace', 'Open Season 2', 'Tom and Jerry & The Wizard of Oz', 'Dino Time', 'Scared Shrekless', 'Amazon Jack 3: Jungo Goes Bananas', "Dug's Special Mission", 'Halloween is Grinch Night', 'Monster High: Welcome to Monster High', 'Plane Crazy', 'Turbo', "Beethoven's 2nd", 'Lonesome Ghosts', 'Monsters University', 'Rock-A-Doodle', 'LasseMajas detektivbyrå - Stella Nostra', 'Blinky Bill the Movie', 'Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics', "Grumpy Cat's Worst Christmas Ever", 'The Dinosaur and the Missing Link: A Prehistoric Tragedy', 'The Shaggy Dog', 'Megamind', 'FernGully 2: The Magical Rescue', 'My Little Pony: Equestria Girls', 'The Giant King', 'Tatu and Patu', 'The Dog Who Saved Christmas', 'Mr. Hobbs Takes a Vacation', 'Ace Ventura Jr: Pet Detective', 'Tri bogatyrya i Shamakhanskaya tsaritsa', 'The Barefoot Executive', 'Die Abrafaxe - Unter schwarzer Flagge', 'Jack and the Beanstalk', 'Barbie: The Princess & The Popstar', 'Foodfight!', 'Otto er et næsehorn', 'Hop', 'Spooky Buddies', 'The Kid & I', 'Monster High: Friday Night Frights', 'Shark Tale', 'Maggie Simpson in The Longest Daycare', "Riley's First Date?", 'Diary of a Wimpy Kid: Dog Days', 'The Reef 2: High Tide', 'Zebra in the Kitchen', 'Ali Baba Bunny', "Pooh's Heffalump Halloween Movie", 'Tangled Ever After', 'Scooby-Doo and the Alien Invaders', 'Werner - Gekotzt wird später!', 'Babes in Toyland', 'Asterix and the Vikings', 'Asterix in Britain', 'Finding Nemo', 'The Gruffalo', 'One Step Ahead of My Shadow', 'Binky Nelson Unpacified', 'That Darn Cat', 'Zootopia', 'Scooby-Doo in Arabian Nights', 'Wings, Legs and Tails', 'The Seventh Brother', 'The Care Bears Adventure in Wonderland', 'Lilo & Stitch 2: Stitch has a Glitch', 'Chicken Little', 'Ernest Saves Christmas', 'Toy Story 2', 'Home on the Range', 'The Great Mouse Detective', 'Midnight Madness', "Mic ...
# True Positives: 3
# Precision Calculation: 3 / 822
# Recall Calculation: 3 / 3
# Similitudes para jumanji:
# Adventures in Dinosaur City: 0.9642857142857144
# City of Ember: 0.9642857142857144
# Cry Wilderness: 0.9642857142857144
# Fantastic Beasts and Where to Find Them: 0.9642857142857144
# Friend of the Jolly Devil: 0.9642857142857144
# Harry Potter and the Chamber of Secrets: 0.9642857142857144
# Harry Potter and the Deathly Hallows: Part 1: 0.9642857142857144
# Harry Potter and the Deathly Hallows: Part 2: 0.9642857142857144
# Harry Potter and the Goblet of Fire: 0.9642857142857144
# Harry Potter and the Half-Blood Prince: 0.9642857142857144
# Title: Jumanji
# Expected Recommendations: {'Jumanji: The Next Level', 'Zathura', 'Jumanji: Welcome to the Jungle'}
# Recommended Titles: {'The Little Ghost', 'Return to Halloweentown', 'The Water Horse', 'A Monster in Paris', 'Magic in the Water', 'Antboy: Revenge of the Red Fury', 'Santa Claus: The Movie', 'The Chronicles of Narnia: Prince Caspian', 'Further Adventures of the Wilderness Family', 'The Slipper and the Rose', 'The Adventures of Tom Sawyer', 'The Peanut Butter Solution', 'Around the World in Eighty Days', 'Charlie, the Lonesome Cougar', 'Sword of Sherwood Forest', 'The Jungle Book', 'Pippi in the South Seas', 'Tarkan and the Blood of the Vikings', 'Slave Girls', 'Harry Potter and the Order of the Phoenix', 'Escape to Witch Mountain', 'Charlie and the Chocolate Factory', 'Dungeons & Dragons: The Book of Vile Darkness', 'The Adventures of Tom Sawyer and Huckleberry Finn', 'The Singing Ringing Tree', 'Mama', 'The Letter for the King', 'The Golden Compass', 'Night at the Museum', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Perri', 'Legends of the Hidden Temple', 'Excalibur', 'H2O Just Add Water - The Movie', 'Harry Potter and the Deathly Hallows: Part 1', 'Friend of the Jolly Devil', 'Night at the Museum: Secret of the Tomb', 'The Cutlass', 'The Princess and the Goblin', 'Jack and the Beanstalk', 'Dark World: Equilibrium', 'Eragon', 'Help for the Holidays', 'Halloweentown High', 'Yeti: The Giant of the 20th Century', 'Tinker Bell and the Great Fairy Rescue', 'Allerleirauh', 'The Wizard of Oz', 'Brenda Starr', "The Gruffalo's Child", 'The Amazing Mr Blunden', "Impy's Wonderland", 'Journey to the Beginning of Time', 'The Croods', 'The Fairy King Of Ar', 'Babe: Pig in the City', 'The NeverEnding Story', 'The Sannikov Land', 'Windstorm', 'Shrek the Third', 'The Snow Queen 2: Refreeze', "Bill & Ted's Bogus Journey", 'Harry Potter and the Half-Blood Prince', 'The Lego Movie', 'The Polar Express', 'Chitty Chitty Bang Bang', 'Treasure Planet', 'The Last Mimzy', 'Die goldene Gans', 'Arthur and the Revenge of Maltazard', 'Ronja Robbersdaughter', 'Pokémon: The Rise of Darkrai', 'Aliens in the Attic', 'The Polar Bear King', 'Inkheart', 'Seventh Son', 'The Cave of the Golden Rose', "VeggieTales: The Wonderful Wizard of Ha's", 'The Lost Medallion: The Adventures of Billy Stone', 'Treasure Buddies', 'Higglety Pigglety Pop! or There Must Be More to Life', 'Oz: The Great and Powerful', 'Swallows and Amazons', 'Barbie and the Secret Door', 'The Rescuers Down Under', 'The BFG', 'The Ewok Adventure', 'The Lost Continent', 'Trouble at Timpetill', 'Mr. Blot in Space', 'The Princess with the Golden Star', 'The Borrowers', 'The Barbarians', 'Secret Society of Souptown', 'Tinker Bell and the Lost Treasure', 'Ruby Red', 'Siv Sleeps Astray', 'Hopelessly Lost', 'King of Katoren', 'The Last Airbender', 'Clash of the Titans', 'Arthur and the Invisibles', 'Vovka in the Kingdom of Far Far Away', 'Rebirth of Mothra II', 'Wee Willie Winkie', 'Kingdom of Crooked Mirrors', 'E.T. the Extra-Terrestrial', 'Thunder and the House of Magic', 'Free Willy', 'The Odyssey', 'The Hobbit: The Desolation of Smaug', 'Mrs. Santa Claus', 'The Loves of Hercules', "Pete's Christmas", 'A Town Called Panic', 'The Wonderful World of the Brothers Grimm', 'Jason and the Argonauts', 'Lightning, the White Stallion', 'Secret of the Wings', 'Snow-White and Rose-Red', 'DuckTales: The Movie - Treasure of the Lost Lamp', 'Little Monsters', "Halloweentown II: Kalabar's Revenge", 'Neverland', 'Hamtaro: The Captive Princess', 'Wizards of Waverly Place: The Movie', 'Dinosaur Island', 'Return to Never Land', 'The Neverending Story II: The Next Chapter', 'Pokémon 4Ever: Celebi - Voice of the Forest', 'Last Action Hero', 'Labors of Hercules', 'Dinotopia', 'War-Gods of the Deep', 'The Skateboard Kid II', 'Pippi Longstocking', 'The Second Jungle Book: Mowgli & Baloo', "A Kid in King Arthur's Court", 'Percy Jackson & the Olympians: The Lightning Thief', 'Die Schöne und das Biest', 'Arthur 3: The War of the Two Worlds', 'Night at the Museum: Battle of the Smithsonian', 'Three Wishes for Cin ...
# True Positives: 0
# Precision Calculation: 0 / 316
# Recall Calculation: 0 / 3
#        title  precision  recall
# 0  GoldenEye   0.003881     1.0
# 1  Toy Story   0.003650     1.0
# 2    Jumanji   0.000000     0.0

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

def evaluate_recommendations_extended(test_df, recommender_func, movies_df_grouped):
    y_true = []
    y_pred = []
    
    # Obtener todos los títulos en el DataFrame de películas
    all_titles = set(movies_df_grouped['title'])
    
    for _, row in test_df.iterrows():
        title = row['title']
        expected_recommendations = set(row['expected_recommendations'])
        recommended_titles = recommender_func(title)
        
        if isinstance(recommended_titles, str):
            recommended_titles = set()
        else:
            recommended_titles = set(recommended_titles)
        
        # Crear etiquetas verdaderas y predicciones
        true_labels = [1 if movie in expected_recommendations else 0 for movie in all_titles]
        pred_labels = [1 if movie in recommended_titles else 0 for movie in all_titles]
        
        y_true.extend(true_labels)
        y_pred.extend(pred_labels)
    
    # Calcular precisión, recuperación y F1-score
    precision = precision_score(y_true, y_pred, average='binary')
    recall = recall_score(y_true, y_pred, average='binary')
    f1 = f1_score(y_true, y_pred, average='binary')
    
    return precision, recall, f1

# Evaluar recomendaciones extendidas
precision, recall, f1 = evaluate_recommendations_extended(recomendacion, movies_df_grouped)
print(f"Precisión: {precision}")
print(f"Recuperación: {recall}")
print(f"F1-Score: {f1}")
# Out:
# Similitudes para goldeneye:
# A Dangerous Man: 0.9642857142857144
# A View to a Kill: 0.9642857142857144
# A Viking Saga: The Darkest Day: 0.9642857142857144
# Angel of Destruction: 0.9642857142857144
# Arabesque: 0.9642857142857144
# As Good As Dead: 0.9642857142857144
# Ballistic: Ecks vs. Sever: 0.9642857142857144
# Beatdown: 0.9642857142857144
# Behind Enemy Lines II: Axis of Evil: 0.9642857142857144
# Black Dog: 0.9642857142857144
# Similitudes para toy story:
# Toy Story 2: 1.0
# Toy Story 3: 1.0
# Toy Story of Terror!: 0.9936096415994076
# A Boy Named Charlie Brown: 0.9642857142857144
# A Close Shave: 0.9642857142857144
# A Flintstones Christmas Carol: 0.9642857142857144
# A Matter of Loaf and Death: 0.9642857142857144
# Ali Baba Bunny: 0.9642857142857144
# Amazon Jack 3: Jungo Goes Bananas: 0.9642857142857144
# An All Dogs Christmas Carol: 0.9642857142857144
# Similitudes para jumanji:
# Adventures in Dinosaur City: 0.9642857142857144
# City of Ember: 0.9642857142857144
# Cry Wilderness: 0.9642857142857144
# Fantastic Beasts and Where to Find Them: 0.9642857142857144
# Friend of the Jolly Devil: 0.9642857142857144
# Harry Potter and the Chamber of Secrets: 0.9642857142857144
# Harry Potter and the Deathly Hallows: Part 1: 0.9642857142857144
# Harry Potter and the Deathly Hallows: Part 2: 0.9642857142857144
# Harry Potter and the Goblet of Fire: 0.9642857142857144
# Harry Potter and the Half-Blood Prince: 0.9642857142857144
# Precisión: 0.0031397174254317113
# Recuperación: 1.0
# F1-Score: 0.006259780907668232
